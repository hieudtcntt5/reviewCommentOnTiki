# %%
import pymongo
from pymongo import MongoClient
from datetime import date
import pandas as pd
client = MongoClient('mongodb+srv://hieudt:77223508@atlascluster.twqbhkg.mongodb.net/test')

db = client["DataLake"]
collection = db["Collection"]

# %%
list_comments = []
for item in collection.find({'date':'2022-11-16'}):
    list_comments.append(item['comment'])
# Out:
# Đánh khá ổn   lưới vợt đan đều   sản phẩm đẹp
# Đóng gói cẩn thận  Hàng như ảnh
# Hình dáng đẹp  nhẹ  vừa tay  giao hàng đúng hạn
# Chất lượng tốt  ship nhanh  vợt cầm chắc tay  cám ơn
# giao hàng nhanh  đúng hàng phục vụ tốt
# Shop rất uy tín và shop rất thân thiện hàng tốt đẹp giá rẻ
# Quá rẻ so với mua ngoài cửa hàng
# 10k/ quả  Mua online 35k/ 10 quả 😍😍😍😍😍
# hàng chất lượng tốt nhen
# giao hàng nhanh đóng gói cẩn thận sản phẩm phù hợp với giá tiền
# quả cầu chất lượng tốt
# Thời gian giao nhanh  Đóng gói rất kỹ
# Cảm nhận đầu tiên khi cầm là khá nhẹ so với tưởng tượng  rất chắc chắn  không nghĩ vợt có giá trên 200k  Rất phù hợp với người mới chơi như mình
# 1 chi tiết nhỏ là khóa kéo cũng có hình cây vợt  dễ thương quá
# Nên mua vì rất xứng đáng với giá tiền ạ
# Shop đáng để tin cậy  sản phẩm tốt và được đóng gói kỹ càng  Cám ơn shop và tiki uy tín nhiều ạ
# Lông cầu hơi giòn nhưng ok so với các cầu cùng phân khúc giá
# Đóng gói cẩn thận  Hàng như ảnh
# ...

# %%
df = pd.DataFrame()
df['Comment'] = list_comments
df.to_excel("Tiki.xlsx")
